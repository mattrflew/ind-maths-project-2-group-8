# %% [markdown]
# # Model 2

# %% [markdown]
# Importing modules for correct directory links and updating parameters if needed.

# %%
import sys
import os
import numpy as np

# %% [markdown]
# Importing model and parameters

# %%
# Add the project root to sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# Now importing from the 'models' folder
from models.model2 import run_model2
from models.params_default import params_default

# Create an instance of the default parameters
params = params_default()

# %% [markdown]
# Updating any paramters we want to change from the default

# %%
# Test out different parameters
params.v0 = 100
params.R_obs = 250
params.N = 50

params.v0_wind = 0
params.v_wind_noise = 0
params.wind_theta = 0
params.wind_theta_noise = 0

params.bird_method = "v-flock"
# etc...

# %% [markdown]
# Running the model

# %%
run_model2(params, plot = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 run_model2(params, plot = True)
#
# File /workspaces/ind-maths-project-2-group-8/models/model2.py:289, in run_model2(params, plot)
#     286 # Do each step, updating the quiver and plotting the new one
#     287 for i in range(params.Nt):
# --> 289     x, y, vx, vy, vx_wind, vy_wind = step(
#     290         x = x,
#     291         y = y,
#     292         vx = vx,
#     293         vy = vy,
#     294         x_obstacle = x_obstacle,
#     295         y_obstacle = y_obstacle,
#     296         x_obstacle_list = x_obstacle_list,
#     297         y_obstacle_list = y_obstacle_list,
#     298         L = params.L,
#     299         v0 = params.v0,
#     300         theta = theta,
#     301         Rsq = params.Rsq,
#     302         R_obs = params.R_obs,
#     303         eta = params.eta,
#     304         fov_angle = params.fov_angle,
#     305         N = params.N,
#     306         dt = params.dt,
#     307         v0_wind = params.v0_wind,
#     308         v_wind_noise = params.v_wind_noise,
#     309         wind_theta = params.wind_theta,
#     310         wind_theta_noise = params.wind_theta_noise
#     311     )
#     313     if plot:
#     314         q = update_quiver(q, x, y, vx, vy)
#
# File /workspaces/ind-maths-project-2-group-8/models/model2.py:221, in step(x, y, vx, vy, x_obstacle, y_obstacle, x_obstacle_list, y_obstacle_list, L, v0, theta, Rsq, R_obs, eta, fov_angle, N, dt, v0_wind, v_wind_noise, wind_theta, wind_theta_noise)
#     215 '''
#     216 Compute a step in the dynamics:
#     217 - update the positions
#     218 - compute the new velocities
#     219 '''
#     220 x, y = update_positions(x, y, vx, vy, dt, L)
# --> 221 theta = update_theta(x, y, theta, Rsq, x_obstacle, y_obstacle, x_obstacle_list, y_obstacle_list, R_obs, eta, N, fov_angle)
#     223 vx_wind, vy_wind = wind_constant_with_noise(v0_wind, v_wind_noise, wind_theta, wind_theta_noise)
#     225 #vx, vy = update_velocities(v0, theta, vx_wind, vy_wind, v_wind_max=10, alpha=0.5)
#
# File /workspaces/ind-maths-project-2-group-8/models/model2.py:184, in update_theta(x, y, theta, Rsq, x_obstacle, y_obstacle, x_obstacle_list, y_obstacle_list, R_obs, eta, N, fov_angle)
#     181 shill_locs, perp_vecs = shill_agents(x[i], y[i], x_obs_in_radius, y_obs_in_radius, x_obstacle_list, y_obstacle_list)
#     183 # Normalise by distance (this should(?) make closer distances more important)
# --> 184 avoidance_vectors = perp_vecs / distances
#     186 # Sum up the avoidance vectors to get the net avoidance direction
#     187 net_avoidance_vector = np.sum(avoidance_vectors, axis=0)
#
# ValueError: operands could not be broadcast together with shapes (1,2) (9,)
