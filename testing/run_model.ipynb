# %%
from parameters import * 
from functions import *

# %%
# Set up a figure
fig, ax = plt.subplots(figsize = (8,8))

# Get obstacles
# Number of obstacles
num_obstacles = 8
nrows = 4
ncols = 2

x_obstacle_list, y_obstacle_list, x_obstacle, y_obstacle = get_obstacles(L, num_obstacles, nrows, ncols)

# Plot obstacle(s) - Plot the "list" to visualise the different obstaclces properly
for xx, yy in zip(x_obstacle_list, y_obstacle_list):
    ax.plot(xx, yy, 'r-')

# # Get the initial configuration

# Random
# x, y, vx, vy, theta = initialize_birds_random(N, L, v0)

# Uniform
theta_start = np.pi/3
x, y, vx, vy, theta = initialize_birds_uniform(N, L, v0, theta_start, eta)

# Plot initial quivers
q = plt.quiver(x,y,vx,vy)

# Set figure parameters
ax.set(xlim=(0, L), ylim=(0, L))
ax.set_aspect('equal')
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

# Do each step, updating the quiver and plotting the new one
for i in range(Nt):
    # print(i)
    x, y, vx, vy = step(x, y, vx, vy, R, r_min, R_obs, x_obstacle_list, y_obstacle_list, N, dt, lam_a, lam_m, lam_o, lam_c)
    q = update_quiver(q, x, y, vx, vy)
    clear_output(wait=True)
    display(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 23
#      16 # # Get the initial configuration
#      17
#      18 # Random
#      19 # x, y, vx, vy, theta = initialize_birds_random(N, L, v0)
#      20
#      21 # Uniform
#      22 theta_start = np.pi/3
# ---> 23 x, y, vx, vy, theta = initialize_birds_uniform(N, L, v0, theta_start, eta)
#      25 # Plot initial quivers
#      26 q = plt.quiver(x,y,vx,vy)
#
# File /workspaces/ind-maths-project-2-group-8/testing/functions.py:208, in initialize_birds_uniform(N, L, v0, theta_start, eta)
#     205 theta = np.ones((len(x),1))*theta_start
#     207 # Add noise
# --> 208 theta = add_noise_theta(theta, eta, N)
#     210 # Bird velocities
#     211 vx = v0 * np.cos(theta)
#
# NameError: name 'add_noise_theta' is not defined
